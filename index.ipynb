# %% [markdown]
# # Data mining with Twitter API and Basic NLP - Lab
#
# ## Introduction
# In this lab, we shall use our Twitter developer account created in the previous lessson and the keys we generated to make some API calls to twitter. We shall look at a number of ways of accessing twitter data which may suit different use cases for twitter API calling. We shall also get an introduction to the `tweepy` Python library to help us with tweet mining and parsing. We shall perform some basic NLP to count the term frequencies etc.
#
# **Note:** You are encourages to consult the Twitter API documentation and `tweepy` library documentation to understand structure of tweets and their properties for accessing specific elements.
#
#
# ## Objectives
#
# You will be able to:
# * Successfully request tweet data from the Twitter API using the Tweepy library
# * Understand the structure of Twitter JSON object structure
# * Parse tweet data and perform basic text analysis using basic NLP techniques
# * Visualize hashtags, mentions from tweets using number of visualization techniques
# * Collect and Parse tweets for a number of use cases

# %% [markdown]
# ## `tweepy`
#
# Tweepy is open-source library, hosted on GitHub and enables Python to communicate with Twitter platform and use its API. Remember , we can access Twitter API and access tweets even without this library. Tweepy makes the whole process simple and easy to understand and execute. Visit [HERE](https://pythonhosted.org/tweepy/index.html) for Tweepy's official documentation and a full list of offered features.
#
# Installing tweepy is easy, it can be pip installed as shown below:

# %%
# uncomment and pip install tweepy if you havent done so already
# !pip install tweepy

# %% [markdown]
# We can now simply import import tweepy in the python working environment

# %%
# Import tweepy
import tweepy

import operator 
import json
from collections import Counter
import pandas as pd
from nltk import bigrams

# %% [markdown]
# So we are now good to move on with setting up tweepy with our user and access tokens.
#
# ### Using tweepy
# Tweepy supports accessing Twitter through OAuth. Twitter has stopped accepting Basic Authentication so OAuth is now the only way to use the Twitter API. In order to create the API object, however, we must first authenticate ourselves with our developer information.
# * Enter your credentials into access_token, access_token_secret, consumer_key, and consumer_secret below

# %%
f = open('access_tokens.json')
tokens = json.load(f)
twitter_tokens = list(tokens['twitter']['first_app_rwilleyii'].keys())
app = tokens['twitter']['first_app_rwilleyii']

# %%
# Set credential variables with appropriate string values
consumer_key = app[twitter_tokens[0]]
consumer_secret = app[twitter_tokens[1]]
access_token = app[twitter_tokens[2]]
access_token_secret = app[twitter_tokens[3]]

# %% [markdown]
# ### Create the Authentication Object
#
# Our next step would be to create tweepy  OAuthHandler instance with our consumer key and secret and set access token and secret using `tweepy.set_access_token`. We can then create an API object with this information.
#
# We shall set it up as shown below:
#
# ```python
# # Create the tweepy authentication object with consumer key and secret
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# # Setting your access token and secret
# auth.set_access_token(access_token, access_token_secret)
# # Creating the API object while passing in auth information
# my_first_api = tweepy.API(auth)
# ```

# %%
# Paste above code here with your credentials to create the Oauth Handler Instance and API object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
my_first_api = tweepy.API(auth)

# %% [markdown]
# If the above cell executed without any error.. congratulations. You can now start mining the Twitter API through `my_first_api` object.
#
# NOTE: If you have a web application and are using a callback URL that needs to be supplied dynamically, you would pass it in like shown below:
# ```python
# auth = tweepy.OAuthHandler(consumer_token, consumer_secret, callback_url)
# ```

# %% [markdown]
# ## Collecting Tweets From Own Timeline - `home_timeline()` method
# A detailed indsight into Tweepy's API object with supported methods to post, retrieve and select tweets can be found at [Tweepy's API Dcoumentation](https://pythonhosted.org/tweepy/api.html#api-reference). It is strongly recommended for you to visit the documentation and study all the relevant methods and arguments that they take.
#
# We can directly collect tweets from our home timeline by applying the method `api.home_timeline()`, which collects 20 most recent tweets by default (including retweeted tweets). To adjust the desired number of tweets (take 100 tweets for example),  we can pass in a parameter value as (count = 100).
#
# By default we get first 140 characters of a tweet. We can, however, optionally pass in an extra argument `tweet_mode='extended'` to get the full length of the tweet. This might be useful if you are interested in analyzing the full text of tweets rather than geographical locations, and hashtags etc. only.
#
# Perform the following
# * See how to get extended tweets [Here](https://github.com/sferik/twitter/issues/880). Use the API object to get tweets from your timeline ,collect 500 tweets.
# * Save the results into `my_timeline_tweets`.

# %%
# Store the tweets it in a variable called my_timeline_tweets
my_timeline_tweets = my_first_api.home_timeline(count=500, tweet_mode='extended')

# %%
# print('-----All Timeline Data-----'.upper())
# for tweet in my_timeline_tweets:
#     print(tweet, '\n')

print('\n\n-----Tweet Text-----'.upper())
for tweet in my_timeline_tweets:
#     if 'hamil' in tweet.text.lower():
        print(tweet.full_text)
# Out:
# -----TWEET TEXT-----
# Nine years since Citizens United, the amount of money in politics hasn't changed dramatically. But who funds politics has: "a handful of donors who make multimillion dollar contributions." The result: disastrous laws like Trump's tax giveaway to the rich. https://t.co/aX8TZdZpKB
# RT @Moonifyio: Fellow sponsor shoutout! #BGCLondon sponsors! @YeahmobiInc @GameAnalytics @ExitGames @gismartmusic @UPLTVofficial @hyprMX #B…
# If your New Year’s resolution involves sticking to a new budget, we’ve got you covered. Use our worksheet to get started early: https://t.co/GV6KHdzbSN
# NEW SHOW: Muse are pleased to add Los Angeles to the Simulation Theory World Tour!
#
# 11 March | Los Angeles, CA | The Forum
#
# Special guest: @WALKTHEMOONband
#
# Presale starts tomorrow. General on sale on Friday. Details here: https://t.co/HcvJkQNpbP
#
# #SimulationTheory #muselive https://t.co/ZHoik7xxkf
# I’ve always drawn inspiration from what Dr. King called life’s most persistent and urgent question: "What are you doing for others?" Let’s honor his legacy by standing up for what is right in our communities and taking steps to make a positive impact on the world.
# It's a good day to make some #goodtrouble. https://t.co/WmFx85FJJk https://t.co/2ZKJHt9Gqc
# Honoring and remembering the life and legacy of Dr. Martin Luther King Jr. #MLKDay https://t.co/GWknPn1c1S
# (See ya Tuesday)
# Gnight and hi and sometimes your head is the heaviest thing so rest that thing and let gravity do its job cmon cmon let’s dream cmon
# Hamilthought, show #14, 1/20/19:
# Nonstop, no matter how tired you are, is SO. MUCH. FUN.
# SO MUCH pretend writing.
# SO MUCH interaction with the whole cast.
# SO MUCH FUN.
# Winter is here. Stay warm, stay safe and remember we are here 24/7 to help you with all your Fios related needs #fiosfam
# Sharing the stage last night at @iheartradio with friends and some of my favourite musicians https://t.co/Yl4mwSmsG1
# Nothing to add, except that Annie Baker and Amy Herzog are awesome, but you knew that already. https://t.co/T7Pga2TfYm
# “To my big brother @dramabookshop...the richest guy in town...” https://t.co/qrVYlKCNqb
# Hamilthought show #13, 1/20/19:
# LADY FILMING IN THE 4th ROW, PLEASE STOP IT,
# I gotta holler just to be heard..."
#
# Please don't make me do that shit again.
# They're 🔐 into the #ProBowl, now 🔐 @JuiceCheck44, @gkittle46 and @DeForestBuckner onto your phone screens 📲 #WallpaperWednesday https://t.co/L49dfcLoRG
# Meanwhile, my wife @VAMNit prepares to add “professor” to her resume...she’s teaching a law seminar at Fordham Law and her first class is tonight! https://t.co/KaTG3bRpca
# This feels like a video from past me, but better production values, thank you Lucy https://t.co/46Jswwm0Q5
# Thanks for crouching in the pic, Jam.
# (Also you do a cool thing in We Know and I stole it &amp; remixed it when I do it now) https://t.co/u22CQ6X82c
# RT @Zach_Acosta: @Lin_Manuel Happy b day to you #39 https://t.co/8KvOaVHm1J
# 🙄 https://t.co/jdVi1z43nM
# And ALL the Starbucks are STILL PLAYING IT https://t.co/w7rxGbOBhP
# Okay so you have until MIDNIGHT PST to enter #Ham4PR50 for your LAST CHANCE to be winners like these lovely people:
#
# @titi_jennie
# @adventureofari
# @Enjay1213
# @nasoncraig
# and Ana O!
#
# Don’t wait til it’s too late - that’s some #WednesdayWisdom https://t.co/9m6RCoJNEL
# *FASHION runway, that is. Tune in to @lifetimetv tonight at 9/8 CT!
# https://t.co/s3jzZl1xly
# 😭 https://t.co/r5Wy9PMQCp
# Then stage management came out like, “they won’t leave, get out there” and I bowed in a bathrobe while 2000 people scream/sang Happy Birthday and I feel like Verdon and how on earth do I sleep between shows now? https://t.co/pQR1E7rktw
# Bow music ended, but no one in the audience left. I was in my underwear halfway changed, but they were all still there chanting... https://t.co/FPAGW8mTze

# %% [markdown]
# ### Tweet JSON
#
# All Twitter APIs that return Tweets provide that data encoded using JavaScript Object Notation (JSON). Here is a summary of information you may find in a typical Tweet JASON.
#
# * Each Tweet has an **author**, a **message**, a **unique ID**, a **timestamp** of when it was posted.
# * Some tweets contain **geo metadata** shared by the user.
# * Each User has a Twitter **name**, an **ID**, a **number of followers**, and most often an account **bio**.
# * With each Tweet we also get **"entity"** objects, which are arrays of common Tweet contents such as **hashtags**, **mentions**, **media**, and **links**.
# * If there are links, the JSON payload can also provide metadata such as the fully unwound **URL** and the webpage’s **title** and **description**.
#
# You may not need all this information for every experiment, but its a good idea to have a general understanding of what data we receive as the result of our API call.
#
# Here is what a Tweet JSON structure looks like:
#
# ---
#
# ```pythpn
# {
#   "created_at": "Thu Apr 06 15:24:15 +0000 2017",
#   "id_str": "850006245121695744",
#   "text": "1\/ Today we\u2019re sharing our vision for the future of the Twitter API platform!\nhttps:\/\/t.co\/XweGngmxlP",
#   "user": {
#     "id": 2244994945,
#     "name": "Twitter Dev",
#     "screen_name": "TwitterDev",
#     "location": "Internet",
#     "url": "https:\/\/dev.twitter.com\/",
#     "description": "Your official source for Twitter Platform news, updates & events. Need technical help? Visit https:\/\/twittercommunity.com\/ \u2328\ufe0f #TapIntoTwitter"
#   },
#   "place": {
#   },
#   "entities": {
#     "hashtags": [
#     ],
#     "urls": [
#       {
#         "url": "https:\/\/t.co\/XweGngmxlP",
#         "unwound": {
#           "url": "https:\/\/cards.twitter.com\/cards\/18ce53wgo4h\/3xo1c",
#           "title": "Building the Future of the Twitter API Platform"
#         }
#       }
#     ],
#     "user_mentions": [
#     ]
#   }
# }
#
#
#
# ```
#
# ---

# %% [markdown]
# ## Parsing Tweet JSON
#
# Let's try to print a single tweet to see what it looks like

# %%
# Unomment below to view contents of the tweet
my_timeline_tweets[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x1a1f091630>, _json={'created_at': 'Mon Jan 21 20:58:27 +0000 2019', 'id': 1087454401911050242, 'id_str': '1087454401911050242', 'full_text': 'Nine years since Citizens United, the amount of money in politics hasn\'t changed dramatically. But who funds politics has: "a handful of donors who make multimillion dollar contributions." The result: disastrous laws like Trump\'s tax giveaway to the rich. https://t.co/aX8TZdZpKB', 'truncated': False, 'display_text_range': [0, 279], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/aX8TZdZpKB', 'expanded_url': 'https://www.brennancenter.org/blog/how-citizens-united-changed-politics-and-shaped-tax-bill', 'display_url': 'brennancenter.org/blog/how-citiz…', 'indices': [256, 279]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1339835893, 'id_str': '1339835893', 'name': 'Hillary Clinton', 'screen_name': 'HillaryClinton', 'location': 'New York, NY', 'description': '2016 Democratic Nominee, SecState, Senator, hair icon. Mom, Wife, Grandma x2, lawyer, advocate, fan of walks in the woods & standing up for our democracy.', 'url': 'https://t.co/99DVW9q1yt', 'entities': {'url': {'urls': [{'url': 'https://t.co/99DVW9q1yt', 'expanded_url': 'http://onwardtogether.org', 'display_url': 'onwardtogether.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 23962815, 'friends_count': 783, 'listed_count': 41779, 'created_at': 'Tue Apr 09 18:04:35 +0000 2013', 'favourites_count': 1138, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 10651, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0057B8', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1339835893/1539631689', 'profile_link_color': '0057B8', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 5430, 'favorite_count': 15563, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'possibly_sensitive_appealable': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 1, 21, 20, 58, 27), id=1087454401911050242, id_str='1087454401911050242', full_text='Nine years since Citizens United, the amount of money in politics hasn\'t changed dramatically. But who funds politics has: "a handful of donors who make multimillion dollar contributions." The result: disastrous laws like Trump\'s tax giveaway to the rich. https://t.co/aX8TZdZpKB', truncated=False, display_text_range=[0, 279], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/aX8TZdZpKB', 'expanded_url': 'https://www.brennancenter.org/blog/how-citizens-united-changed-politics-and-shaped-tax-bill', 'display_url': 'brennancenter.org/blog/how-citiz…', 'indices': [256, 279]}]}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in ...

# %% [markdown]
# So the Tweet here is in the JSON format , which we can parse as dictionaries.
#
# We can iterate through collected tweets in `my_timeline_tweets` to access any of the properties of each tweet. Let's print the name and location of users with `.user.name`, `.user.locations` propoerties, and content of the each tweet using the `.text` property.
#
# **NOTE:** Use `.full_text` in case of using `tweet_mode='extended'` OR just `.text` if you havent passed in the extended argument.
#
# #### Iterate through `my_timeline_tweets` and print the usernames, location and text of the each collected tweet.

# %%
# Iterate through my_timeline_tweets and print the name, location and text for each tweet using k:v pairs addressing
for tweet in my_timeline_tweets:
#     if 'hamil' in tweet.text.lower():
        print('\nName: {}\nLocation: {}\nTweet: {}\n'.format(tweet.user.name, tweet.user.location, tweet.full_text))
        print('-------------------------------------------------------------------------------------------------------')

# EXAMPLE OUTPUT
    
# Dr. Data&Science 🎃
# SFO | ATL | 🛫
# RT @RalstonReports: The turnout models are looking better for Democrats in Nevada as they boost their statewide lead a bit, but long way to…
# ----------------------------------------------------------------------------
# Data Science Central
# Seattle, WA
# [Cheat Sheet] Python Basics For Data Science https://t.co/fH07ZFF9zw
# ----------------------------------------------------------------------------
# Dr. Data&Science 🎃
# SFO | ATL | 🛫
# RT @Popehat: NYT:  Well, Okay, But Are People Mean To Trump?
# Everyone: Can you not
# NYT:  Jazz: What If Black People Got Involved In Jazz
# Ev…
# .
# .
# .
# .
# IBM Data Science
# San Francisco, CA
# Essential math for data science: A curated list including functions, variables, equations, graphs, statistics, linear algebra, calculus, discrete math, optimization, and operation research topics, whew. Check it out here: https://t.co/0JtcPuJ04N via @kdnuggets #datascience https://t.co/E2m2trORG9
# ----------------------------------------------------------------------------
# Data Science Central
# Los Angeles, CA
# The Mathematics of Machine Learning https://t.co/GUBZVT8NUj
# Out:
# Name: Hillary Clinton
# Location: New York, NY
# Tweet: Nine years since Citizens United, the amount of money in politics hasn't changed dramatically. But who funds politics has: "a handful of donors who make multimillion dollar contributions." The result: disastrous laws like Trump's tax giveaway to the rich. https://t.co/aX8TZdZpKB
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Braavo
# Location: New York, NY
# Tweet: RT @Moonifyio: Fellow sponsor shoutout! #BGCLondon sponsors! @YeahmobiInc @GameAnalytics @ExitGames @gismartmusic @UPLTVofficial @hyprMX #B…
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Nelnet
# Location: Lincoln, NE
# Tweet: If your New Year’s resolution involves sticking to a new budget, we’ve got you covered. Use our worksheet to get started early: https://t.co/GV6KHdzbSN
#
# -------------------------------------------------------------------------------------------------------
#
# Name: muse
# Location:
# Tweet: NEW SHOW: Muse are pleased to add Los Angeles to the Simulation Theory World Tour!
#
# 11 March | Los Angeles, CA | The Forum
#
# Special guest: @WALKTHEMOONband
#
# Presale starts tomorrow. General on sale on Friday. Details here: https://t.co/HcvJkQNpbP
#
# #SimulationTheory #muselive https://t.co/ZHoik7xxkf
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Barack Obama
# Location: Washington, DC
# Tweet: I’ve always drawn inspiration from what Dr. King called life’s most persistent and urgent question: "What are you doing for others?" Let’s honor his legacy by standing up for what is right in our communities and taking steps to make a positive impact on the world.
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Hillary Clinton
# Location: New York, NY
# Tweet: It's a good day to make some #goodtrouble. https://t.co/WmFx85FJJk https://t.co/2ZKJHt9Gqc
#
# -------------------------------------------------------------------------------------------------------
#
# Name: San Francisco 49ers
# Location: Santa Clara, CA
# Tweet: Honoring and remembering the life and legacy of Dr. Martin Luther King Jr. #MLKDay https://t.co/GWknPn1c1S
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: (See ya Tuesday)
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Gnight and hi and sometimes your head is the heaviest thing so rest that thing and let gravity do its job cmon cmon let’s dream cmon
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Hamilthought, show #14, 1/20/19:
# Nonstop, no matter how tired you are, is SO. MUCH. FUN.
# SO MUCH pretend writing.
# SO MUCH interaction with the whole cast.
# SO MUCH FUN.
#
# -------------------------------------------------------------------------------------------------------
#
# Name:
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Meanwhile, my wife @VAMNit prepares to add “professor” to her resume...she’s teaching a law seminar at Fordham Law and her first class is tonight! https://t.co/KaTG3bRpca
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: This feels like a video from past me, but better production values, thank you Lucy https://t.co/46Jswwm0Q5
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Thanks for crouching in the pic, Jam.
# (Also you do a cool thing in We Know and I stole it &amp; remixed it when I do it now) https://t.co/u22CQ6X82c
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: RT @Zach_Acosta: @Lin_Manuel Happy b day to you #39 https://t.co/8KvOaVHm1J
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: 🙄 https://t.co/jdVi1z43nM
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: And ALL the Starbucks are STILL PLAYING IT https://t.co/w7rxGbOBhP
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Okay so you have until MIDNIGHT PST to enter #Ham4PR50 for your LAST CHANCE to be winners like these lovely people:
#
# @titi_jennie
# @adventureofari
# @Enjay1213
# @nasoncraig
# and Ana O!
#
# Don’t wait til it’s too late - that’s some #WednesdayWisdom https://t.co/9m6RCoJNEL
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Southwest Airlines
# Location: Dallas, Texas
# Tweet: *FASHION runway, that is. Tune in to @lifetimetv tonight at 9/8 CT!
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: https://t.co/s3jzZl1xly
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: 😭 https://t.co/r5Wy9PMQCp
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Then stage management came out like, “they won’t leave, get out there” and I bowed in a bathrobe while 2000 people scream/sang Happy Birthday and I feel like Verdon and how on earth do I sleep between shows now? https://t.co/pQR1E7rktw
#
# -------------------------------------------------------------------------------------------------------
#
# Name: Lin-Manuel Miranda
# Location: Washington Heights
# Tweet: Bow music ended, but no one in the audience left. I was in my underwear halfway changed, but they were all still there chanting... https://t.co/FPAGW8mTze
#
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# Thats is great. We are getting some meaningful information indeed.
#
# #### Before we proceed ....
# *We are using a test account and following a number of AI, Data science and Tech groups/companies to progress through the lab. Based on your own preferences , your results may be different than what you see here. You are encouraged to ask some meaningful questions and parse the JSON around how YOU use twitter.**

# %% [markdown]
# ###  Store the Tweets JSON File

# %% [markdown]
# It is always a good idea to store the tweets as a JSON file as executing above cells will bring in new tweets and will keep re-writing the object. This can have negative impacts on your analysis (unless you are analyzing live streams).
# * Store the `my_timeline_tweets` JSON object in `tweets.json` file.

# %%
# Store my_timeline_tweets as a JSON file
tweets = []
for tweet in my_timeline_tweets:
    tweets.append(tweet._json)
with open('tweets.json', 'w') as f:
    json.dump(tweets, f)

# %% [markdown]
# #### Open `tweets.json` and inspect its contents in relation to the JSON object shown below.

# %%
f = open('tweets.json')
my_json_tweets = json.load(f)
my_json_tweets
# Out:
# [{'created_at': 'Mon Jan 21 20:58:27 +0000 2019',
#   'id': 1087454401911050242,
#   'id_str': '1087454401911050242',
#   'full_text': 'Nine years since Citizens United, the amount of money in politics hasn\'t changed dramatically. But who funds politics has: "a handful of donors who make multimillion dollar contributions." The result: disastrous laws like Trump\'s tax giveaway to the rich. https://t.co/aX8TZdZpKB',
#   'truncated': False,
#   'display_text_range': [0, 279],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/aX8TZdZpKB',
#      'expanded_url': 'https://www.brennancenter.org/blog/how-citizens-united-changed-politics-and-shaped-tax-bill',
#      'display_url': 'brennancenter.org/blog/how-citiz…',
#      'indices': [256, 279]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1339835893,
#    'id_str': '1339835893',
#    'name': 'Hillary Clinton',
#    'screen_name': 'HillaryClinton',
#    'location': 'New York, NY',
#    'description': '2016 Democratic Nominee, SecState, Senator, hair icon. Mom, Wife, Grandma x2, lawyer, advocate, fan of walks in the woods & standing up for our democracy.',
#    'url': 'https://t.co/99DVW9q1yt',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/99DVW9q1yt',
#        'expanded_url': 'http://onwardtogether.org',
#        'display_url': 'onwardtogether.org',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 23962815,
#    'friends_count': 783,
#    'listed_count': 41779,
#    'created_at': 'Tue Apr 09 18:04:35 +0000 2013',
#    'favourites_count': 1138,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 10651,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0057B8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1339835893/1539631689',
#    'profile_link_color': '0057B8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 5430,
#   'favorite_count': 15563,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 20:07:09 +0000 2019',
#   'id': 1087441491465854977,
#   'id_str': '1087441491465854977',
#   'full_text': 'RT @Moonifyio: Fellow sponsor shoutout! #BGCLondon sponsors! @YeahmobiInc @GameAnalytics @ExitGames @gismartmusic @UPLTVofficial @hyprMX #B…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [{'text': 'BGCLondon', 'indices': [40, 50]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Moonifyio',
#      'name': 'Moonify.io',
#      'id': 856603399604903936,
#      'id_str': '856603399604903936',
#      'indices': [3, 13]},
#     {'screen_name': 'YeahmobiInc',
#      'name': 'Yeahmobi',
#      'id': 1654994773,
#      'id_str': '1654994773',
#      'indices': [61, 73]},
#     {'screen_name': 'GameAnalytics',
#      'name': 'GameAnalytics',
#      'id': 153729505,
#      'id_str': '153729505',
#      'indices': [74, 88]},
#     {'screen_name': 'ExitGames',
#      'name': 'Exit Games Photon',
#      'id': 310312655,
#      'id_str': '310312655',
#      'indices': [89, 99]},
#     {'screen_name': 'gismartmusic',
#      'name': 'Gismart',
#      'id': 3402578091,
#      'id_str': '3402578091',
#      'indices': [100, 113]},
#     {'screen_name': 'UPLTVofficial',
#      'name': 'UPLTV',
#      'id': 956394532001599488,
#      'id_str': '956394532001599488',
#      'indices': [114, 128]},
#     {'screen_name': 'hyprMX',
#      'name': 'hyprMX',
#      'id': 2565525559,
#      'id_str': '2565525559',
#      'indices': [129, 136]}],
#    'urls': []},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3233966029,
#    'id_str': '3233966029',
#    'name': 'Braavo',
#    'screen_name': 'getbraavo',
#    'location': 'New York, NY',
#    'description': 'Intelligent funding for mobile growth',
#    'url': 'https://t.co/3VTsoZzWsP',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/3VTsoZzWsP',
#        'expanded_url': 'http://www.getbraavo.com',
#        'display_url': 'getbraavo.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 966,
#    'friends_count': 1317,
#    'listed_count': 57,
#    'created_at': 'Tue Jun 02 18:21:47 +0000 2015',
#    'favourites_count': 878,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 511,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1068533824445956100/JjEd82MG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068533824445956100/JjEd82MG_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3233966029/1543593162',
#    'profile_link_color': '262F6A',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jan 21 14:25:04 +0000 2019',
#    'id': 1087355402063413249,
#    'id_str': '1087355402063413249',
#    'full_text': 'Fellow sponsor shoutout! #BGCLondon sponsors! @YeahmobiInc @GameAnalytics @ExitGames @gismartmusic @UPLTVofficial @hyprMX #Bunkervfx #iqzone @yellowheadinc @bangodotcom @SynativeVideo @TabTale @londongamesfest @Soomla @getbraavo https://t.co/h7YJJiOy1o',
#    'truncated': False,
#    'display_text_range': [0, 228],
#    'entities': {'hashtags': [{'text': 'BGCLondon', 'indices': [25, 35]},
#      {'text': 'Bunkervfx', 'indices': [122, 132]},
#      {'text': 'iqzone', 'indices': [133, 140]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'YeahmobiInc',
#       'name': 'Yeahmobi',
#       'id': 1654994773,
#       'id_str': '1654994773',
#       'indices': [46, 58]},
#      {'screen_name': 'GameAnalytics',
#       'name': 'GameAnalytics',
#       'id': 153729505,
#       'id_str': '153729505',
#       'indices': [59, 73]},
#      {'screen_name': 'ExitGames',
#       'name': 'Exit Games Photon',
#       'id': 310312655,
#       'id_str': '310312655',
#       'indices': [74, 84]},
#      {'screen_name': 'gismartmusic',
#       'name': 'Gismart',
#       'id': 3402578091,
#       'id_str': '3402578091',
#       'indices': [85, 98]},
#      {'screen_name': 'UPLTVofficial',
#       'name': 'UPLTV',
#       'id': 956394532001599488,
#       'id_str': '956394532001599488',
#       'indices': [99, 113]},
#      {'screen_name': 'hyprMX',
#       'name': 'hyprMX',
#       'id': 2565525559,
#       'id_str': '2565525559',
#       'indices': [114, 121]},
#      {'screen_name': 'yellowheadinc',
#       'name': 'yellowHEAD',
#       'id': 2292772177,
#       'id_str': '2292772177',
#       'indices': [141, 155]},
#      {'screen_name': 'bangodotcom',
#       'name': 'Bango',
#       'id': 38454460,
#       'id_str': '38454460',
#       'indices': [156, 168]},
#      {'screen_name': 'SynativeVideo',
#       'name': 'Synative',
#       'id': 984629696053723137,
#       'id_str': '984629696053723137',
#       'indices': [169, 183]},
#      {'screen_name': 'TabTale',
#       'name': 'TabTale',
#       'id': 243754596,
#       'id_str': '243754596',
#       'indices': [184, 192]},
#      {'screen_name': 'londongamesfest',
#       'name': 'London Games Festival',
#       'id': 182779444,
#       'id_str': '182779444',
#       'indices': [193, 209]},
#      {'screen_name': 'Soomla',
#       'name': 'SOOMLA',
#       'id': 611477419,
#       'id_str': '611477419',
#       'indices': [210, 217]},
#      {'screen_name': 'getbraavo',
#       'name': 'Braavo',
#       'id': 3233966029,
#       'id_str': '3233966029',
#       'indices': [218, 228]}],
#     'urls': [],
#     'media': [{'id': 1087355398322032640,
#       'id_str': '1087355398322032640',
#       'indices': [229, 252],
#       'media_url': 'http://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'url': 'https://t.co/h7YJJiOy1o',
#       'display_url': 'pic.twitter.com/h7YJJiOy1o',
#       'expanded_url': 'https://twitter.com/Moonifyio/status/1087355402063413249/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1536, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1087355398322032640,
#       'id_str': '1087355398322032640',
#       'indices': [229, 252],
#       'media_url': 'http://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'url': 'https://t.co/h7YJJiOy1o',
#       'display_url': 'pic.twitter.com/h7YJJiOy1o',
#       'expanded_url': 'https://twitter.com/Moonifyio/status/1087355402063413249/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1536, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 856603399604903936,
#     'id_str': '856603399604903936',
#     'name': 'Moonify.io',
#     'screen_name': 'Moonifyio',
#     'location': 'Montpellier, France',
#     'description': '✈️Blockchain Gamer Connects✈️\nA #blockchain #monetization platform for digital publishers. #games, #cryptogames, #streaming  platforms, #crowdfunding',
#     'url': 'https://t.co/Y7ewp87RoE',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Y7ewp87RoE',
#         'expanded_url': 'http://www.moonify.io',
#         'display_url': 'moonify.io',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 218,
#     'friends_count': 75,
#     'listed_count': 9,
#     'created_at': 'Mon Apr 24 20:19:00 +0000 2017',
#     'favourites_count': 174,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 405,
#     'lang': 'fr',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/958677681649963008/9ggumeB1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958677681649963008/9ggumeB1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/856603399604903936/1517401467',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 19:00:02 +0000 2019',
#   'id': 1087424598151491585,
#   'id_str': '1087424598151491585',
#   'full_text': 'If your New Year’s resolution involves sticking to a new budget, we’ve got you covered. Use our worksheet to get started early: https://t.co/GV6KHdzbSN',
#   'truncated': False,
#   'display_text_range': [0, 151],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/GV6KHdzbSN',
#      'expanded_url': 'https://bit.ly/2v0yYS7',
#      'display_url': 'bit.ly/2v0yYS7',
#      'indices': [128, 151]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 355682433,
#    'id_str': '355682433',
#    'name': 'Nelnet',
#    'screen_name': 'Nelnet',
#    'location': 'Lincoln, NE',
#    'description': 'Visit https://t.co/WImV20PaTh, or log in to your https://t.co/WImV20PaTh account to chat M-F, 8 a.m.-10:30 p.m. EST. Terms of Service: https://t.co/QS380A5iA7',
#    'url': 'http://t.co/xsNPWoiCDp',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/xsNPWoiCDp',
#        'expanded_url': 'http://Nelnet.com',
#        'display_url': 'Nelnet.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/WImV20PaTh',
#        'expanded_url': 'http://Nelnet.com',
#        'display_url': 'Nelnet.com',
#        'indices': [6, 29]},
#       {'url': 'https://t.co/WImV20PaTh',
#        'expanded_url': 'http://Nelnet.com',
#        'display_url': 'Nelnet.com',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/QS380A5iA7',
#        'expanded_url': 'http://on.fb.me/1mTAWdn',
#        'display_url': 'on.fb.me/1mTAWdn',
#        'indices': [135, 158]}]}},
#    'protected': False,
#    'followers_count': 17967,
#    'friends_count': 80,
#    'listed_count': 66,
#    'created_at': 'Mon Aug 15 18:44:55 +0000 2011',
#    'favourites_count': 60,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6019,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'DBE68A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/694162267848495105/Gx0SXs0P_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/694162267848495105/Gx0SXs0P_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/355682433/1490126302',
#    'profile_link_color': '00A0D5',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F3F5E7',
#    'profile_text_color': '00A0D5',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 17:10:45 +0000 2019',
#   'id': 1087397097308110849,
#   'id_str': '1087397097308110849',
#   'full_text': 'NEW SHOW: Muse are pleased to add Los Angeles to the Simulation Theory World Tour!\n\n11 March | Los Angeles, CA | The Forum\n\nSpecial guest: @WALKTHEMOONband \n\nPresale starts tomorrow. General on sale on Friday. Details here: https://t.co/HcvJkQNpbP\n\n#SimulationTheory #muselive https://t.co/ZHoik7xxkf',
#   'truncated': False,
#   'display_text_range': [0, 276],
#   'entities': {'hashtags': [{'text': 'SimulationTheory',
#      'indices': [249, 266]},
#     {'text': 'muselive', 'indices': [267, 276]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'WALKTHEMOONband',
#      'name': 'WALK THE MOON',
#      'id': 153491693,
#      'id_str': '153491693',
#      'indices': [139, 155]}],
#    'urls': [{'url': 'https://t.co/HcvJkQNpbP',
#      'expanded_url': 'http://www.muse.mu/news/los-angeles-11-march-310356',
#      'display_url': 'muse.mu/news/los-angel…',
#      'indices': [224, 247]}],
#    'media': [{'id': 1087396874313760768,
#      'id_str': '1087396874313760768',
#      'indices': [277, 300],
#      'media_url': 'http://pbs.twimg.com/media/Dxc1sidXgAAhepk.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Dxc1sidXgAAhepk.jpg',
#      'url': 'https://t.co/ZHoik7xxkf',
#      'display_url': 'pic.twitter.com/ZHoik7xxkf',
#      'expanded_url': 'https://twitter.com/muse/status/1087397097308110849/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 524, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 693, 'h': 900, 'resize': 'fit'},
#       'medium': {'w': 693, 'h': 900, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1087396874313760768,
#      'id_str': '1087396874313760768',
#      'indices': [277, 300],
#      'media_url': 'http://pbs.twimg.com/media/Dxc1sidXgAAhepk.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/Dxc1sidXgAAhepk.jpg',
#      'url': 'https://t.co/ZHoik7xxkf',
#      'display_url': 'pic.twitter.com/ZHoik7xxkf',
#      'expanded_url': 'https://twitter.com/muse/status/1087397097308110849/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 524, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 693, 'h': 900, 'resize': 'fit'},
#       'medium': {'w': 693, 'h': 900, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 14583400,
#    'id_str': '14583400',
#    'name': 'muse',
#    'screen_name': 'muse',
#    'location': '',
#    'description': 'New album Simulation Theory is out now! Tickets for the 2019 #SimulationTheory World Tour available now!',
#    'url': 'https://t.co/UQgpRGFYSU',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/UQgpRGFYSU',
#        'expanded_url': 'http://muse.mu',
#        'display_url': 'muse.mu',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2683639,
#    'friends_count': 4,
#    'listed_count': 21997,
#    'created_at': 'Tue Apr 29 11:31:20 +0000 2008',
#    'favourites_count': 209,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 3032,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/793901137690783746/sdXDkkpz_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/793901137690783746/sdXDkkpz_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14583400/1543610190',
#    'profile_link_color': 'D533C9',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 131,
#   'favorite_count': 917,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 16:14:42 +0000 2019',
#   'id': 1087382991901474816,
#   'id_str': '1087382991901474816',
#   'full_text': 'I’ve always drawn inspiration from what Dr. King called life’s most persistent and urgent question: "What are you doing for others?" Let’s honor his legacy by standing up for what is right in our communities and taking steps to make a positive impact on the world.',
#   'truncated': False,
#   'display_text_range': [0, 264],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 813286,
#    'id_str': '813286',
#    'name': 'Barack Obama',
#    'screen_name': 'BarackObama',
#    'location': 'Washington, DC',
#    'description': 'Dad, husband, President, citizen.',
#    'url': 'https://t.co/93Y27HEnnX',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/93Y27HEnnX',
#        'expanded_url': 'https://www.obama.org/',
#        'display_url': 'obama.org',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 104321912,
#    'friends_count': 616379,
#    'listed_count': 230009,
#    'created_at': 'Mon Mar 05 22:08:25 +0000 2007',
#    'favourites_count': 11,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 15574,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': True,
#    'profile_background_color': '77B0DC',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822547732376207360/5g0FC8XX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822547732376207360/5g0FC8XX_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/813286/1502508746',
#    'profile_link_color': '2574AD',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C2E0F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 116173,
#   'favorite_count': 495501,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 15:20:14 +0000 2019',
#   'id': 1087369284060397570,
#   'id_str': '1087369284060397570',
#   'full_text': "It's a good day to make some #goodtrouble. https://t.co/WmFx85FJJk https://t.co/2ZKJHt9Gqc",
#   'truncated': False,
#   'display_text_range': [0, 66],
#   'entities': {'hashtags': [{'text': 'goodtrouble', 'indices': [29, 41]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/WmFx85FJJk',
#      'expanded_url': 'http://MLKDay.gov',
#      'display_url': 'MLKDay.gov',
#      'indices': [43, 66]}],
#    'media': [{'id': 1087369279002021889,
#      'id_str': '1087369279002021889',
#      'indices': [67, 90],
#      'media_url': 'http://pbs.twimg.com/media/DxccmR6WkAE1QFm.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DxccmR6WkAE1QFm.jpg',
#      'url': 'https://t.co/2ZKJHt9Gqc',
#      'display_url': 'pic.twitter.com/2ZKJHt9Gqc',
#      'expanded_url': 'https://twitter.com/HillaryClinton/status/1087369284060397570/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1087369279002021889,
#      'id_str': '1087369279002021889',
#      'indices': [67, 90],
#      'media_url': 'http://pbs.twimg.com/media/DxccmR6WkAE1QFm.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DxccmR6WkAE1QFm.jpg',
#      'url': 'https://t.co/2ZKJHt9Gqc',
#      'display_url': 'pic.twitter.com/2ZKJHt9Gqc',
#      'expanded_url': 'https://twitter.com/HillaryClinton/status/1087369284060397570/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1339835893,
#    'id_str': '1339835893',
#    'name': 'Hillary Clinton',
#    'screen_name': 'HillaryClinton',
#    'location': 'New York, NY',
#    'description': '2016 Democratic Nominee, SecState, Senator, hair icon. Mom, Wife, Grandma x2, lawyer, advocate, fan of walks in the woods & standing up for our democracy.',
#    'url': 'https://t.co/99DVW9q1yt',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/99DVW9q1yt',
#        'expanded_url': 'http://onwardtogether.org',
#        'display_url': 'onwardtogether.org',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 23962815,
#    'friends_count': 783,
#    'listed_count': 41779,
#    'created_at': 'Tue Apr 09 18:04:35 +0000 2013',
#    'favourites_count': 1138,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 10651,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0057B8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1339835893/1539631689',
#    'profile_link_color': '0057B8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 6653,
#   'favorite_count': 33359,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 14:30:00 +0000 2019',
#   'id': 1087356644466380805,
#   'id_str': '1087356644466380805',
#   'full_text': 'Honoring and remembering the life and legacy of Dr. Martin Luther King Jr. #MLKDay https://t.co/GWknPn1c1S',
#   'truncated': False,
#   'display_text_range': [0, 82],
#   'entities': {'hashtags': [{'text': 'MLKDay', 'indices': [75, 82]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1087225375451574272,
#      'id_str': '1087225375451574272',
#      'indices': [83, 106],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1087225375451574272/img/TC4nETgiTthCzDwq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1087225375451574272/img/TC4nETgiTthCzDwq.jpg',
#      'url': 'https://t.co/GWknPn1c1S',
#      'display_url': 'pic.twitter.com/GWknPn1c1S',
#      'expanded_url': 'https://twitter.com/49ers/status/1087356644466380805/video/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1024, 'h': 576, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1024, 'h': 576, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1087225375451574272,
#      'id_str': '1087225375451574272',
#      'indices': [83, 106],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1087225375451574272/img/TC4nETgiTthCzDwq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1087225375451574272/img/TC4nETgiTthCzDwq.jpg',
#      'url': 'https://t.co/GWknPn1c1S',
#      'display_url': 'pic.twitter.com/GWknPn1c1S',
#      'expanded_url': 'https://twitter.com/49ers/status/1087356644466380805/video/1',
#      'type': 'video',
#      'sizes': {'medium': {'w': 1024, 'h': 576, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1024, 'h': 576, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 6000,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1087225375451574272/pl/GTAQp3MMUcN11goO.m3u8?tag=11'},
#        {'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1087225375451574272/vid/320x180/zoGzRWHz3U92U73T.mp4?tag=11'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1087225375451574272/vid/1024x576/Zw82y6WTXxFUu5Dt.mp4?tag=11'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1087225375451574272/vid/640x360/e5uZ_BXQsX8rruvZ.mp4?tag=11'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 43403778,
#    'id_str': '43403778',
#    'name': 'San Francisco 49ers',
#    'screen_name': '49ers',
#    'location': 'Santa Clara, CA',
#    'description': 'Official Twitter account of the 5-time Super Bowl Champion San Francisco 49ers | #WPMOYChallengeGould | Class Notice for Persons with Mobility Disabilities 👇',
#    'url': 'https://t.co/pABAnVPlaa',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/pABAnVPlaa',
#        'expanded_url': 'https://www.49ers.com/about-us/classnotice',
#        'display_url': '49ers.com/about-us/class…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2061664,
#    'friends_count': 297,
#    'listed_count': 9831,
#    'created_at': 'Fri May 29 20:34:37 +0000 2009',
#    'favourites_count': 8464,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 41802,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1072174712367669248/wfllTfD0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1072174712367669248/wfllTfD0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43403778/1544570707',
#    'profile_link_color': 'AA0000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'CCCCCC',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 190,
#   'favorite_count': 980,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 03:14:03 +0000 2019',
#   'id': 1087186535605256192,
#   'id_str': '1087186535605256192',
#   'full_text': '(See ya Tuesday)',
#   'truncated': False,
#   'display_text_range': [0, 16],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1087186368600649728,
#   'in_reply_to_status_id_str': '1087186368600649728',
#   'in_reply_to_user_id': 79923701,
#   'in_reply_to_user_id_str': '79923701',
#   'in_reply_to_screen_name': 'Lin_Manuel',
#   'user': {'id': 79923701,
#    'id_str': '79923701',
#    'name': 'Lin-Manuel Miranda',
#    'screen_name': 'Lin_Manuel',
#    'location': 'Washington Heights',
#    'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#    'url': 'https://t.co/1U0poRLi4I',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#        'expanded_url': 'http://Linmanuel.com',
#        'display_url': 'Linmanuel.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#        'expanded_url': 'https://hispanicfederation.org/unidos',
#        'display_url': 'hispanicfederation.org/unidos',
#        'indices': [45, 68]}]}},
#    'protected': False,
#    'followers_count': 2698839,
#    'friends_count': 2912,
#    'listed_count': 7364,
#    'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#    'favourites_count': 42210,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 57645,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 95,
#   'favorite_count': 5373,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 03:13:23 +0000 2019',
#   'id': 1087186368600649728,
#   'id_str': '1087186368600649728',
#   'full_text': 'Gnight and hi and sometimes your head is the heaviest thing so rest that thing and let gravity do its job cmon cmon let’s dream cmon',
#   'truncated': False,
#   'display_text_range': [0, 132],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 79923701,
#    'id_str': '79923701',
#    'name': 'Lin-Manuel Miranda',
#    'screen_name': 'Lin_Manuel',
#    'location': 'Washington Heights',
#    'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#    'url': 'https://t.co/1U0poRLi4I',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#        'expanded_url': 'http://Linmanuel.com',
#        'display_url': 'Linmanuel.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#        'expanded_url': 'https://hispanicfederation.org/unidos',
#        'display_url': 'hispanicfederation.org/unidos',
#        'indices': [45, 68]}]}},
#    'protected': False,
#    'followers_count': 2698839,
#    'friends_count': 2912,
#    'listed_count': 7364,
#    'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#    'favourites_count': 42210,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 57645,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2738,
#   'favorite_count': 24219,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 03:11:24 +0000 2019',
#   'id': 1087185868232843264,
#   'id_str': '1087185868232843264',
#   'full_text': 'Hamilthought, show #14, 1/20/19:\nNonstop, no matter how tired you are, is SO. MUCH. FUN. \nSO MUCH pretend writing. \nSO MUCH interaction with the whole cast. \nSO MUCH FUN.',
#   'truncated': False,
#   'display_text_range': [0, 170],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 79923701,
#    'id_str': '79923701',
#    'name': 'Lin-Manuel Miranda',
#    'screen_name': 'Lin_Manuel',
#    'location': 'Washington Heights',
#    'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#    'url': 'https://t.co/1U0poRLi4I',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#        'expanded_url': 'http://Linmanuel.com',
#        'display_url': 'Linmanuel.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#        'expanded_url': 'https://hispanicfederation.org/unidos',
#        'display_url': 'hispanicfederation.org/unidos',
#        'indices': [45, 68]}]}},
#    'protected': False,
#    'followers_count': 2698839,
#    'friends_count': 2912,
#    'listed_count': 7364,
#    'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#    'favourites_count': 42210,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 57645,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1520,
#   'favorite_count': 31518,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 00:00:00 +0000 2019',
#   'id': 1087137699830611971,
#   'id_str': '1087137699830611971',
#   'full_text': 'Winter is here. Stay warm, stay safe and remember we are here 24/7 to help you with all your Fios related needs #fiosfam',
#   'truncated': False,
#   'display_text_range': [0, 120],
#   'entities': {'hashtags': [{'text': 'fiosfam', 'indices': [112, 120]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 37435412,
#    'id_str': '37435412',
#    'name': 'Verizon Support',
#    'screen_name': 'VerizonSupport',
#    'location': '',
#    'description': 'Tweets from the Verizon Solutions Center to help with your TV, phone & Internet services.  We have #PowerfulAnswers',
#    'url': 'http://t.co/67UQA4DN2h',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/67UQA4DN2h',
#        'expanded_url': 'http://www.verizon.com/support',
#        'display_url': 'verizon.com/support',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 199477,
#    'friends_count': 81512,
#    'listed_count': 811,
#    'created_at': 'Sun May 03 15:27:19 +0000 2009',
#    'favourites_count': 889,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 709156,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834897414091833345/HLT1b80p_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/834897414091833345/HLT1b80p_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/37435412/1394742087',
#    'profile_link_color': '3333CC',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'ECECEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 6,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Jan 20 23:34:10 +0000 2019',
#   'id': 1087131200995643392,
#   'id_str': '1087131200995643392',
#   'full_text': 'Sharing the stage last night at @iheartradio with friends and some of my favourite musicians https://t.co/Yl4mwSmsG1',
#   'truncated': False,
#   'display_text_range': [0, 116],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'iHeartRadio',
#      'name': 'iHeartRadio',
#      'id': 46116615,
#      'id_str': '46116615',
#      'indices': [32, 44]}],
#    'urls': [{'url': 'https://t.co/Yl4mwSmsG1',
#      'expanded_url': 'https://www.instagram.com/p/Bs3jdPylqyD/?utm_source=ig_twitter_share&igshid=ct8ctbmw1crw',
#      'display_url': 'instagram.com/p/Bs3jdPylqyD/…',
#      'indices': [93, 116]}]},
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 271310204,
#    'id_str': '271310204',
#    'name': 'Matt Bellamy',
#    'screen_name': 'MattBellamy',
#    'location': '',
#    'description': '',
#    'url': 'https://t.co/fhBS7E2D0R',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/fhBS7E2D0R',
#        'expanded_url': 'http://www.muse.mu',
#        'display_url': 'muse.mu',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 520514,
#    'friends_count': 34,
#    'listed_count': 3667,
#    'created_at': 'Thu Mar 24 07:45:52 +0000 2011',
#    'favourites_count': 20,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
# ...
#    'in_reply_to_screen_name': 'Lin_Manuel',
#    'user': {'id': 240000773,
#     'id_str': '240000773',
#     'name': 'jama',
#     'screen_name': 'jxmaris_',
#     'location': '',
#     'description': '"He who does not weep does not see." ❁ ❁ ❁ uprrp || nyu || ugr',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 737,
#     'friends_count': 693,
#     'listed_count': 12,
#     'created_at': 'Tue Jan 18 23:04:09 +0000 2011',
#     'favourites_count': 8326,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 21697,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1087030839827943425/G3ToMl9A_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1087030839827943425/G3ToMl9A_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/240000773/1543863122',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 306,
#    'favorite_count': 3371,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'es'},
#   'retweet_count': 575,
#   'favorite_count': 8456,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'und'},
#  {'created_at': 'Wed Jan 16 20:43:18 +0000 2019',
#   'id': 1085638648740102144,
#   'id_str': '1085638648740102144',
#   'full_text': 'Then stage management came out like, “they won’t leave, get out there” and I bowed in a bathrobe while 2000 people scream/sang Happy Birthday and I feel like Verdon and how on earth do I sleep between shows now? https://t.co/pQR1E7rktw',
#   'truncated': False,
#   'display_text_range': [0, 211],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/pQR1E7rktw',
#      'expanded_url': 'https://twitter.com/Lin_Manuel/status/1085638003383504898',
#      'display_url': 'twitter.com/Lin_Manuel/sta…',
#      'indices': [212, 235]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 79923701,
#    'id_str': '79923701',
#    'name': 'Lin-Manuel Miranda',
#    'screen_name': 'Lin_Manuel',
#    'location': 'Washington Heights',
#    'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#    'url': 'https://t.co/1U0poRLi4I',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#        'expanded_url': 'http://Linmanuel.com',
#        'display_url': 'Linmanuel.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#        'expanded_url': 'https://hispanicfederation.org/unidos',
#        'display_url': 'hispanicfederation.org/unidos',
#        'indices': [45, 68]}]}},
#    'protected': False,
#    'followers_count': 2698839,
#    'friends_count': 2912,
#    'listed_count': 7364,
#    'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#    'favourites_count': 42210,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 57645,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1085638003383504898,
#   'quoted_status_id_str': '1085638003383504898',
#   'quoted_status_permalink': {'url': 'https://t.co/pQR1E7rktw',
#    'expanded': 'https://twitter.com/Lin_Manuel/status/1085638003383504898',
#    'display': 'twitter.com/Lin_Manuel/sta…'},
#   'quoted_status': {'created_at': 'Wed Jan 16 20:40:44 +0000 2019',
#    'id': 1085638003383504898,
#    'id_str': '1085638003383504898',
#    'full_text': 'Bow music ended, but no one in the audience left. I was in my underwear halfway changed, but they were all still there chanting... https://t.co/FPAGW8mTze',
#    'truncated': False,
#    'display_text_range': [0, 130],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/FPAGW8mTze',
#       'expanded_url': 'https://twitter.com/lin_manuel/status/1085637520220700672',
#       'display_url': 'twitter.com/lin_manuel/sta…',
#       'indices': [131, 154]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 79923701,
#     'id_str': '79923701',
#     'name': 'Lin-Manuel Miranda',
#     'screen_name': 'Lin_Manuel',
#     'location': 'Washington Heights',
#     'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#     'url': 'https://t.co/1U0poRLi4I',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#         'expanded_url': 'http://Linmanuel.com',
#         'display_url': 'Linmanuel.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#         'expanded_url': 'https://hispanicfederation.org/unidos',
#         'display_url': 'hispanicfederation.org/unidos',
#         'indices': [45, 68]}]}},
#     'protected': False,
#     'followers_count': 2698839,
#     'friends_count': 2912,
#     'listed_count': 7364,
#     'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#     'favourites_count': 42210,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 57645,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': True,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1085637520220700672,
#    'quoted_status_id_str': '1085637520220700672',
#    'quoted_status_permalink': {'url': 'https://t.co/FPAGW8mTze',
#     'expanded': 'https://twitter.com/lin_manuel/status/1085637520220700672',
#     'display': 'twitter.com/lin_manuel/sta…'},
#    'retweet_count': 587,
#    'favorite_count': 11674,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'retweet_count': 1254,
#   'favorite_count': 17336,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Jan 16 20:40:44 +0000 2019',
#   'id': 1085638003383504898,
#   'id_str': '1085638003383504898',
#   'full_text': 'Bow music ended, but no one in the audience left. I was in my underwear halfway changed, but they were all still there chanting... https://t.co/FPAGW8mTze',
#   'truncated': False,
#   'display_text_range': [0, 130],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/FPAGW8mTze',
#      'expanded_url': 'https://twitter.com/lin_manuel/status/1085637520220700672',
#      'display_url': 'twitter.com/lin_manuel/sta…',
#      'indices': [131, 154]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 79923701,
#    'id_str': '79923701',
#    'name': 'Lin-Manuel Miranda',
#    'screen_name': 'Lin_Manuel',
#    'location': 'Washington Heights',
#    'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#    'url': 'https://t.co/1U0poRLi4I',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#        'expanded_url': 'http://Linmanuel.com',
#        'display_url': 'Linmanuel.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#        'expanded_url': 'https://hispanicfederation.org/unidos',
#        'display_url': 'hispanicfederation.org/unidos',
#        'indices': [45, 68]}]}},
#    'protected': False,
#    'followers_count': 2698839,
#    'friends_count': 2912,
#    'listed_count': 7364,
#    'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#    'favourites_count': 42210,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 57645,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1085637520220700672,
#   'quoted_status_id_str': '1085637520220700672',
#   'quoted_status_permalink': {'url': 'https://t.co/FPAGW8mTze',
#    'expanded': 'https://twitter.com/lin_manuel/status/1085637520220700672',
#    'display': 'twitter.com/lin_manuel/sta…'},
#   'quoted_status': {'created_at': 'Wed Jan 16 20:38:49 +0000 2019',
#    'id': 1085637520220700672,
#    'id_str': '1085637520220700672',
#    'full_text': 'WHAT. JUST. HAPPENED OUT THERE. AFTER THE BOW.\n😭who’s got pics?',
#    'truncated': False,
#    'display_text_range': [0, 63],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 79923701,
#     'id_str': '79923701',
#     'name': 'Lin-Manuel Miranda',
#     'screen_name': 'Lin_Manuel',
#     'location': 'Washington Heights',
#     'description': 'Former substitute teacher. Hamilton NY & 🇵🇷. https://t.co/KNRgSFxx3A',
#     'url': 'https://t.co/1U0poRLi4I',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1U0poRLi4I',
#         'expanded_url': 'http://Linmanuel.com',
#         'display_url': 'Linmanuel.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/KNRgSFxx3A',
#         'expanded_url': 'https://hispanicfederation.org/unidos',
#         'display_url': 'hispanicfederation.org/unidos',
#         'indices': [45, 68]}]}},
#     'protected': False,
#     'followers_count': 2698839,
#     'friends_count': 2912,
#     'listed_count': 7364,
#     'created_at': 'Mon Oct 05 04:59:07 +0000 2009',
#     'favourites_count': 42210,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 57645,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086661723661234178/pNV1eJYr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/79923701/1547915341',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': True,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 636,
#    'favorite_count': 18630,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'retweet_count': 587,
#   'favorite_count': 11674,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}]

# %% [markdown]
# ## NATURAL LANGUAGE PROCESSING
#
# Twitter data is of the most favorite dataset for data scientists and Natural Language Processing (NLP) researchers. Besides its magnanimous size, Twitter data has other unique qualities as well: it comprises of real-life conversations, limited word length, rich variety, and real-time data stream. Advanced analytics on Twitter data needs one to go beyond the words and parse sentences into syntactic representations to develop a better contextual understanding of the tweet content. We shall cover more of that in our sections dedicated to NLP.
#
# ![](https://static1.squarespace.com/static/5552e2d6e4b098f713cf2613/t/56e3930327d4bdfdac7c34a9/1457754894624/?format=750w)
#
# Here we shall look at some basic techniques that you might want to use for cleaning text data and look for important words, mentions, URLs  or hashtags etc.
#
# #### Good old word count ..
#
# A very fundamental NLP skill, without using any complicated algorithms is to count the occurrences of words/terms (known as **TERM FREQUENCIES** of TFs). With this, we can observe what are the terms most commonly used in the data set.
#
# ### Tokenization
#
# Tokenization is an NLP specific term which concerns with breaking down a text document (like a tweet) into its tokens (words/terms). Below we have a simple custom tokenization routine that will parse each tweet and split it into words/terms to capture Twitter-specific aspects of the text, such as **#hashtags**, **@mentions**, **emoticons** and **URLs**. In order to tokenize , you simply need to pass each tweet to the `preprocess_tweet()` function below and it will be split into its constituent terms.

# %%
# A SIMPLE TOKENZIER IMPLEMENTAION 

# Import Regular Expressions
import re

# Identify some basic emoticon elements (face, nose, mouth )- you are encouraged to add more for other emoticons
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""

# Identify Twitter specific elements in a tweet
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess_tweet(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %% [markdown]
# The code above uses a lot of regular expressions to search for twitter specific terms. Let's pass in a sample tweet to `preprocess_tweet` function and inspect the output.

# %%
example_tweet = 'ExampleTweet @datascienceguy: You are an NLP superstar :D http://example.com #NLP #datascience :P'
print(preprocess_tweet(example_tweet))
# Out:
# ['ExampleTweet', '@datascienceguy', ':', 'You', 'are', 'an', 'NLP', 'superstar', ':D', 'http://example.com', '#NLP', '#datascience', ':P']

# %% [markdown]
# So here you can see that each word, URL, emoticon has been sucessfully identified as a **Term**. Now we can do some basic analysis with these terms.

# %% [markdown]
# ### Count Term Frequencies
#
# As a first step, we can simply count the total number of occurances of teach term. Keep in mind that at this stage , we are also counting punctuation marks and common words like "the" "of" "for etc.
#
# Perform following tasks.
# * Load the JSON file `tweets.json` into a new variable called `data`.
# * In order to keep track of the frequencies while we are processing the tweets, we can use `collections.Counter()`  from the `Counter` library, which behaves is a dictionary (term: count) with some useful methods like `update()` and `most_common()`. [Here is a link to official doc. for consultation](https://docs.python.org/2/library/collections.html).
# * Iterate through the list of tweets update the term counter using `.update()` method for all terms after each iteration.
# * Count all the terms and list top ten most common terms

# %%
data = my_json_tweets
data[:2]
# Out:
# [{'created_at': 'Mon Jan 21 20:58:27 +0000 2019',
#   'id': 1087454401911050242,
#   'id_str': '1087454401911050242',
#   'full_text': 'Nine years since Citizens United, the amount of money in politics hasn\'t changed dramatically. But who funds politics has: "a handful of donors who make multimillion dollar contributions." The result: disastrous laws like Trump\'s tax giveaway to the rich. https://t.co/aX8TZdZpKB',
#   'truncated': False,
#   'display_text_range': [0, 279],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/aX8TZdZpKB',
#      'expanded_url': 'https://www.brennancenter.org/blog/how-citizens-united-changed-politics-and-shaped-tax-bill',
#      'display_url': 'brennancenter.org/blog/how-citiz…',
#      'indices': [256, 279]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1339835893,
#    'id_str': '1339835893',
#    'name': 'Hillary Clinton',
#    'screen_name': 'HillaryClinton',
#    'location': 'New York, NY',
#    'description': '2016 Democratic Nominee, SecState, Senator, hair icon. Mom, Wife, Grandma x2, lawyer, advocate, fan of walks in the woods & standing up for our democracy.',
#    'url': 'https://t.co/99DVW9q1yt',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/99DVW9q1yt',
#        'expanded_url': 'http://onwardtogether.org',
#        'display_url': 'onwardtogether.org',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 23962815,
#    'friends_count': 783,
#    'listed_count': 41779,
#    'created_at': 'Tue Apr 09 18:04:35 +0000 2013',
#    'favourites_count': 1138,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 10651,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0057B8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051914952192057344/xwZDe7zt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1339835893/1539631689',
#    'profile_link_color': '0057B8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 5430,
#   'favorite_count': 15563,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Jan 21 20:07:09 +0000 2019',
#   'id': 1087441491465854977,
#   'id_str': '1087441491465854977',
#   'full_text': 'RT @Moonifyio: Fellow sponsor shoutout! #BGCLondon sponsors! @YeahmobiInc @GameAnalytics @ExitGames @gismartmusic @UPLTVofficial @hyprMX #B…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [{'text': 'BGCLondon', 'indices': [40, 50]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Moonifyio',
#      'name': 'Moonify.io',
#      'id': 856603399604903936,
#      'id_str': '856603399604903936',
#      'indices': [3, 13]},
#     {'screen_name': 'YeahmobiInc',
#      'name': 'Yeahmobi',
#      'id': 1654994773,
#      'id_str': '1654994773',
#      'indices': [61, 73]},
#     {'screen_name': 'GameAnalytics',
#      'name': 'GameAnalytics',
#      'id': 153729505,
#      'id_str': '153729505',
#      'indices': [74, 88]},
#     {'screen_name': 'ExitGames',
#      'name': 'Exit Games Photon',
#      'id': 310312655,
#      'id_str': '310312655',
#      'indices': [89, 99]},
#     {'screen_name': 'gismartmusic',
#      'name': 'Gismart',
#      'id': 3402578091,
#      'id_str': '3402578091',
#      'indices': [100, 113]},
#     {'screen_name': 'UPLTVofficial',
#      'name': 'UPLTV',
#      'id': 956394532001599488,
#      'id_str': '956394532001599488',
#      'indices': [114, 128]},
#     {'screen_name': 'hyprMX',
#      'name': 'hyprMX',
#      'id': 2565525559,
#      'id_str': '2565525559',
#      'indices': [129, 136]}],
#    'urls': []},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3233966029,
#    'id_str': '3233966029',
#    'name': 'Braavo',
#    'screen_name': 'getbraavo',
#    'location': 'New York, NY',
#    'description': 'Intelligent funding for mobile growth',
#    'url': 'https://t.co/3VTsoZzWsP',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/3VTsoZzWsP',
#        'expanded_url': 'http://www.getbraavo.com',
#        'display_url': 'getbraavo.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 966,
#    'friends_count': 1317,
#    'listed_count': 57,
#    'created_at': 'Tue Jun 02 18:21:47 +0000 2015',
#    'favourites_count': 878,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 511,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1068533824445956100/JjEd82MG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068533824445956100/JjEd82MG_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3233966029/1543593162',
#    'profile_link_color': '262F6A',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Jan 21 14:25:04 +0000 2019',
#    'id': 1087355402063413249,
#    'id_str': '1087355402063413249',
#    'full_text': 'Fellow sponsor shoutout! #BGCLondon sponsors! @YeahmobiInc @GameAnalytics @ExitGames @gismartmusic @UPLTVofficial @hyprMX #Bunkervfx #iqzone @yellowheadinc @bangodotcom @SynativeVideo @TabTale @londongamesfest @Soomla @getbraavo https://t.co/h7YJJiOy1o',
#    'truncated': False,
#    'display_text_range': [0, 228],
#    'entities': {'hashtags': [{'text': 'BGCLondon', 'indices': [25, 35]},
#      {'text': 'Bunkervfx', 'indices': [122, 132]},
#      {'text': 'iqzone', 'indices': [133, 140]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'YeahmobiInc',
#       'name': 'Yeahmobi',
#       'id': 1654994773,
#       'id_str': '1654994773',
#       'indices': [46, 58]},
#      {'screen_name': 'GameAnalytics',
#       'name': 'GameAnalytics',
#       'id': 153729505,
#       'id_str': '153729505',
#       'indices': [59, 73]},
#      {'screen_name': 'ExitGames',
#       'name': 'Exit Games Photon',
#       'id': 310312655,
#       'id_str': '310312655',
#       'indices': [74, 84]},
#      {'screen_name': 'gismartmusic',
#       'name': 'Gismart',
#       'id': 3402578091,
#       'id_str': '3402578091',
#       'indices': [85, 98]},
#      {'screen_name': 'UPLTVofficial',
#       'name': 'UPLTV',
#       'id': 956394532001599488,
#       'id_str': '956394532001599488',
#       'indices': [99, 113]},
#      {'screen_name': 'hyprMX',
#       'name': 'hyprMX',
#       'id': 2565525559,
#       'id_str': '2565525559',
#       'indices': [114, 121]},
#      {'screen_name': 'yellowheadinc',
#       'name': 'yellowHEAD',
#       'id': 2292772177,
#       'id_str': '2292772177',
#       'indices': [141, 155]},
#      {'screen_name': 'bangodotcom',
#       'name': 'Bango',
#       'id': 38454460,
#       'id_str': '38454460',
#       'indices': [156, 168]},
#      {'screen_name': 'SynativeVideo',
#       'name': 'Synative',
#       'id': 984629696053723137,
#       'id_str': '984629696053723137',
#       'indices': [169, 183]},
#      {'screen_name': 'TabTale',
#       'name': 'TabTale',
#       'id': 243754596,
#       'id_str': '243754596',
#       'indices': [184, 192]},
#      {'screen_name': 'londongamesfest',
#       'name': 'London Games Festival',
#       'id': 182779444,
#       'id_str': '182779444',
#       'indices': [193, 209]},
#      {'screen_name': 'Soomla',
#       'name': 'SOOMLA',
#       'id': 611477419,
#       'id_str': '611477419',
#       'indices': [210, 217]},
#      {'screen_name': 'getbraavo',
#       'name': 'Braavo',
#       'id': 3233966029,
#       'id_str': '3233966029',
#       'indices': [218, 228]}],
#     'urls': [],
#     'media': [{'id': 1087355398322032640,
#       'id_str': '1087355398322032640',
#       'indices': [229, 252],
#       'media_url': 'http://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'url': 'https://t.co/h7YJJiOy1o',
#       'display_url': 'pic.twitter.com/h7YJJiOy1o',
#       'expanded_url': 'https://twitter.com/Moonifyio/status/1087355402063413249/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1536, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1087355398322032640,
#       'id_str': '1087355398322032640',
#       'indices': [229, 252],
#       'media_url': 'http://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DxcP-UWWkAAHkLu.jpg',
#       'url': 'https://t.co/h7YJJiOy1o',
#       'display_url': 'pic.twitter.com/h7YJJiOy1o',
#       'expanded_url': 'https://twitter.com/Moonifyio/status/1087355402063413249/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 2048, 'h': 1536, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 856603399604903936,
#     'id_str': '856603399604903936',
#     'name': 'Moonify.io',
#     'screen_name': 'Moonifyio',
#     'location': 'Montpellier, France',
#     'description': '✈️Blockchain Gamer Connects✈️\nA #blockchain #monetization platform for digital publishers. #games, #cryptogames, #streaming  platforms, #crowdfunding',
#     'url': 'https://t.co/Y7ewp87RoE',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Y7ewp87RoE',
#         'expanded_url': 'http://www.moonify.io',
#         'display_url': 'moonify.io',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 218,
#     'friends_count': 75,
#     'listed_count': 9,
#     'created_at': 'Mon Apr 24 20:19:00 +0000 2017',
#     'favourites_count': 174,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 405,
#     'lang': 'fr',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/958677681649963008/9ggumeB1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958677681649963008/9ggumeB1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/856603399604903936/1517401467',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %%
from collections import Counter
cnt = Counter()

for tweet in data:
    words = preprocess_tweet(tweet['full_text'])
    for word in words:
        cnt[word] += 1
cnt.most_common(n=10)
# Count all terms frequency from the saved JSON file

# [(':', 142), ('.', 94), (',', 92), ('RT', 91), ('the', 81), ('to', 65), 
# ('…', 65), ('of', 65), ('and', 64), ('a', 58)]
# Out:
# [('.', 241),
#  (',', 144),
#  ('the', 122),
#  ('’', 92),
#  ('to', 88),
#  (':', 83),
#  ('you', 76),
#  ('I', 75),
#  ('and', 66),
#  ('!', 62)]

# %% [markdown]
# Right so in above output , we see that our punctuation marks and common terms like "the" and "of" etc. are being shown as top terms. The next step is to remove these words to focus on more IMPORTANT words. this step is called the "Stop-word Removal".

# %% [markdown]
# ### Stop Word Removal
#
# Every language has words that are very common. While their use in the language is very important, they do not carry any clear meaning on their own like conjunctions,  adverbs, etc. In the language of NLP , these are referred to as **Stop-words**.
# Stop-word removal is one important step that should be considered during the pre-processing stages. One can build a custom list of stop-words, or use available lists (e.g. [NLTK](https://www.nltk.org/) provides a simple list for English stop-words). You can search Internet for domain specific stop-words as well as some words may carry a deeper meaning in one domain while could be meaningless in another. (Try thinking of a few examples).
#
# Given the nature of our data and our tokenization, we should also be careful with all the punctuation marks and with terms like RT (used for re-tweets), via (used to mention the original author of an article or a re-tweet), ... (used for ongoing tweet) etc. Below is a stop word list that we build from nltk + punctuation + some twitter specific stop words. Your are encouraged to add more to it.

# %%
# Create a stop word list from nltk stopwords, punctuation marks and some twitter specific stop terms
import nltk
from nltk.corpus import stopwords
import string
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'RT',  'via', 'The', 'the', '…', '¡', '’', 'I', '️', '”', '“', '🇵', '🇷', '❤']
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", '!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~', 'rt', 'RT', 'via', 'The', 'the', '…', '¡', '’', 'I', '️', '”', '“', '🇵', '🇷', '❤']

# %% [markdown]
# Now we can simply use this list to clean up our tweets. Perform following tasks
# * Clear count_all to start a new counter
# * Change the routine above to collect tweets while filtering with above stop word list.
# * Use list comprehension to only include terms NOT found in the stop-word list
# * Print the top ten most common terms.

# %%
# Calculate term frequencies
cnt = Counter()

for tweet in data:
    words = preprocess_tweet(tweet['full_text'])
    for word in words:
        if word in stop:
            pass
        else:
            cnt[word] += 1
cnt.most_common(n=10)
# add_to_stop = []
# for word in cnt.most_common(n=10):
#     add_to_stop.append(word[0])
# add_to_stop

# [('Vote', 35), ('#ODSCWest', 29), ('Data', 26), ('#ODSC', 21), ('#DataScience', 18), 
# ('’', 16), ('AI', 16), ('#AI', 14), ('@ODSC', 13), ('data', 12)]
# Out:
# [('get', 15),
#  ('amp', 15),
#  ('like', 14),
#  ('You', 14),
#  ('show', 12),
#  ('recalculating', 12),
#  ('route', 12),
#  ('We', 11),
#  ('1', 10),
#  ('19', 10)]

# %% [markdown]
# So this looks much better, still not perfect though. Remember this is an iterative process and you would want to refine your stop word list. Here we see some useful terms like commonly mentioned hashtags etc. with lots of unwanted terms that xcould be included as stop words. Do some survey on other stop-word lists available online and include them with you own criteria.

# %% [markdown]
# ## More Term Filtering
#
# Besides stop-word removal, we can further customize the list of terms we are interested in.
#
# ### Calculate Document  Frequency
#
# > The number of documents in the collection that contain a term t.
#
# We can also calculate document frequency which shows us the number of documents (tweets) that show a specific term. For this we can make small tweaks to the code we used to calculate all terms frequencies for all document. Here we shall count every term only once in every document and see how many documents contain a specific term. For this you need to clear the counter, and perform following tasks for every tweet.
#
# * Calculate frequencies for all terms while filtering out the stop words
# * Make a set of unique terms (counted only once) for each tweet
# * Update the counter
#
# * Show the top 20 terms from the counter

# %%
# Calculate document frequencies
stop = stopwords.words('english') + punctuation + ['rt',  'via', 'the', '…', '¡', '’', 'i', '️', '”', '“', '🇵', '🇷', '❤']
# stop.extend(['get', 'like', 'amp', 'we', 'you', 'this', '1', '19', '7', 'one', 'let', 'us', 'got', 'today', 'thing'])
cnt = Counter()

for tweet in data:
    words = preprocess_tweet(tweet['full_text'])
    update_list = []
    for word in set(words):
        if word.lower() in stop or word in stop:
            pass
        else:
            update_list.append(word.lower())
    cnt.update(update_list)
cnt.most_common(n=10)


# [('#ODSCWest', 29), ('Data', 24), ('#ODSC', 21), ('#DataScience', 18), ('’', 14), 
# ('AI', 14), ('#AI', 14), ('@ODSC', 13), ('data', 12), ('Science', 11), ('A', 11), ('2018', 11), 
# ('West', 11), ('3', 9), ('amp', 9), ('Join', 8), ('Nov', 8), ('How', 8), ('#bordercollie', 8), ('Python', 7)]
# Out:
# [('get', 18),
#  ('show', 16),
#  ('like', 14),
#  ('amp', 12),
#  ('birthday', 10),
#  ('new', 9),
#  ('let', 9),
#  ('today', 9),
#  ('one', 9),
#  ('happy', 9)]

# %% [markdown]
# Do you see any improvements in results ? You may need to work more on the stop word list and maybe filter out the numerical terms like dates and other numbers. You could also filter out terms with length less than a set threshold e.g. only include terms that carry 4 or more characters. Like we saw earlier, it is an iterative process and we may have to revisit our parsing code a few times to get more meaningful answers.
#
# ### Calculate Hashtag Frequencies
#
# A Hashtag in a tweet is just another term , identified by a hash (#) sign. Let's iterate through our corpus of tweets again collecting all terms that are hashtags i.e. start with a #. Perform following tasks for each tweet:
# * Reset the counter
# * Collect the terms starting with # sign
# * Update the counter
# * List and visualize top 20 hashtags as bar charts and label properly

# %%
# Calculte top 20 hashtags
def top_hashtags(data, n=20):
    cnt = Counter()

    for tweet in data:
        words = preprocess_tweet(tweet['full_text'])
        update_list = []
        for word in words:
            if word == '#':
                pass
            elif word[0] == '#':
                update_list.append(word.lower())
        cnt.update(update_list)
    return cnt.most_common(n=n)

my_top_hashtags = top_hashtags(data)
# Plot top 20 hashtags
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_hashtags(my_top_hashtags):
    x, y = [], []
    for word in my_top_hashtags:
        x.append(word[0])
        y.append(word[1])

    plt.figure(figsize=(20, 8))
    plt.bar(x, y)
    plt.xlabel('Hashtag')
    plt.xticks(rotation='vertical')
    plt.ylabel('Frequency Count')
    plt.title('Most Common Hashtags')
    plt.show

plot_hashtags(my_top_hashtags)
# [('#ODSCWest', 29), ('#ODSC', 21), ('#DataScience', 18), ('#AI', 14), ('#bordercollie', 8), 
# ('#', 6), ('#abdsc', 4), ('#BigData', 4), ('#MachineLearning', 4), ('#datascience', 4), 
# ('#BorderCollie', 4), ('#DeepLearning', 2), ('#Python', 2), ('#puppy', 2), ('#dogs', 2), 
#('#dogsoftwitter', 2), ('#collie', 2), ('#earlyvote', 2), ('#TeamAbrams', 1), ('#GAGov', 1)]

# %% [markdown]
# ### Calculate Bi-gram Frequencies
#
# While the frequent terms post cleaning, stop removal etc. represent a clear topic, simple term frequencies don’t give us a deeper explanation of what the text is about. To put things in context, let’s consider sequences of two terms combined (a.k.a. bigrams).
#
# > **A bigram is a sequence of two adjacent elements from a string of tokens, which are typically letters, syllables, or words. A bigram is an n-gram for n=2. The frequency distribution of every bigram in a string is commonly used for simple statistical analysis of text in many applications, including in computational linguistics, cryptography, speech recognition, and so on.**(wiki)
#
# We can import bigrams function from nltk library to automatically create bigrams from a given sequence of text. Here is a quick demo:

# %%
from nltk import bigrams 
from nltk import trigrams

text = 'This is a very simple sentence'
terms = [term for term in preprocess_tweet(text)]
terms_bigram = bigrams(terms)
print(terms)
list(terms_bigram)
# Out:
# ['This', 'is', 'a', 'very', 'simple', 'sentence']
# [('This', 'is'),
#  ('is', 'a'),
#  ('a', 'very'),
#  ('very', 'simple'),
#  ('simple', 'sentence')]

# %% [markdown]
# The combination of two words may help get the deeper understanding of the tweet. You could also calculate trigrams or even higher , but it might get computationally expensive.
#
# You are required to calculate the frequencies of bigrams in the collected tweets, and find the most frequent combination of two adjacent elements. Perform following tasks:
#
# * Clear the counter
# * Collect all the terms excluding stop words, hashtags and mentions
# * Calculte the bigrams for each tweet and update counter with frequencies
# * Display and top 20 bigrams

# %%
# Show the frequency of top 20 bigrams in the corpus
cnt = Counter()

for tweet in data:
    words = preprocess_tweet(tweet['full_text'])
    update_list = []
    for word in words:
        if word.lower() in stop or word in stop:
            pass
        else:
            update_list.append(word.lower())
    words_bigram = bigrams(update_list)
    cnt.update(words_bigram)
cnt.most_common(n=20)


# [(('Vote', 'Vote'), 33), (('Data', 'Science'), 11), (('San', 'Francisco'), 7), 
# (('West', '2018'), 7), (('Oct', '31'), 5), (('31', 'Nov'), 5), (('Nov', '3'), 5), 
# (('Don', '’'), 4), (('Francisco', 'Oct'), 4), (('Big', 'Data'), 4), (('machine', 'learning'), 3), 
# (('data', 'scientists'), 3), (('data', 'science'), 3), (('Machine', 'Learning'), 3), 
# (('Deep', 'Learning'), 3), (('Data', 'Scientist'), 3), (('LIVESTREAM', 'Pass'), 3), 
# (('I', '’'), 3), (('\u2066', '\u2069'), 3), (('Cheat', 'Sheet'), 2)]
# Out:
# [(('recalculating', 'route'), 12),
#  (('hamilthought', 'show'), 8),
#  (('happy', 'birthday'), 8),
#  (('24', '7'), 6),
#  (('route', 'let'), 6),
#  (('let', 'go'), 5),
#  (('last', 'night'), 4),
#  (('40', 'th'), 4),
#  (('🤣', '🤣'), 4),
#  (('cmon', 'cmon'), 3),
#  (('streaming', 'live'), 3),
#  (('live', 'atlanta'), 3),
#  (('atlanta', 'twitter'), 3),
#  (('twitter', 'saturday'), 3),
#  (('saturday', 'feb'), 3),
#  (('feb', '2'), 3),
#  (('2', '11'), 3),
#  (('11', 'p'), 3),
#  (('p', 'et'), 3),
#  (('tommy', 'kail'), 3)]

# %% [markdown]
# So we start to see something a bit more meaningful. For this case, we see more meaningul combinations of words which clearly indicate themes or recurring topics within tweets. A bit more effort can really get us results that can be easily analyzed to get some real insights.

# %% [markdown]
# ## Collecting Tweets From A User's Timeline - `user_timeline()` method
#
#
# For some analyses, you may be interested in collecting tweets from someone else's timeline. We can use `user_timeline()` method to achieve this while passing `id=name` parameter to identify the user. Let's collect last 100 tweets from "FlatironSchool" and visualize top 10 hashtags and mentions. Apart from the new method `user_timeline()`, everything else will remain the same as above. Perform following tasks:
#
# * Collect last 200 tweets from "FlatironSchool"
# * Calculate top 10 hashtags and mentions as terms from collected tweets
# * Visualize results as bargraphs in both cases

# %%
# Calculate and Visulize top 10 hashtags in last 200 tweets from FlatironSchool's Timeline

fi_timeline = my_first_api.user_timeline(id='FlatironSchool', count=200, tweet_mode='extended')

fi_tweets = []
for tweet in fi_timeline:
    fi_tweets.append(tweet._json)
with open('fi_tweets.json', 'w') as file:
    json.dump(fi_tweets, file)
    
file = open('fi_tweets.json')
fi_json_tweets = json.load(file)

flatiron_hashtags = top_hashtags(fi_json_tweets, n=10)
flatiron_hashtags, plot_hashtags(flatiron_hashtags)
# Out:
# ([('#changethings', 22),
#   ('#100daysofcode', 6),
#   ('#datascience', 5),
#   ('#flatironchicago', 3),
#   ('#lgbtq', 3),
#   ('#mondaymotivation', 3),
#   ('#techtowealth', 2),
#   ('#momscancode', 2),
#   ('#flatironalum', 2),
#   ('#flatironlondon', 2)],
#  None)

# %%
# Calculate and Visulize top 10 mentions in last 200 tweets from FlatironSchool's Timeline 
# Exclude @FlatironSchool mentions 
cnt = Counter()
for tweet in fi_json_tweets:
    update_list = []
    if '@FlatironSchool' in tweet['full_text']:
        pass
    else:
        words = preprocess_tweet(tweet['full_text'])
        for word in words:
            if word[0] == '#':
                update_list.append(word)
        cnt.update(update_list)

cnt.most_common(10), plot_hashtags(cnt.most_common(10))
# Out:
# ([('#changethings', 17),
#   ('#ChangeThings', 4),
#   ('#flatironchicago', 3),
#   ('#mondaymotivation', 3),
#   ('#MomsCanCode', 2),
#   ('#flatironalum', 2),
#   ('#flatironlondon', 2),
#   ('#100DaysOfCode', 2),
#   ('#datascience', 2),
#   ('#flatironhouston', 2)],
#  None)

# %% [markdown]
# ## Collecting Tweets Using a Keyword -  `.search()` method
#
# Let’s look at one last use case i.e. getting the most recent tweets that contain a specific keyword. This can be extremely useful if you want to monitor specifically mentioned topics in the Twitter world, or even to see how your business is getting mentioned. We shall use Twitter standard search API whith `q=query` parameter to pass our search query.
#
# Let’s say we want to see how FlatironSchool is being been mentioned on Twitter. We would like to see which Twitter  users are being mentioned in conjunction with FlatironSchool. Remember maxiumum number of tweets you can mine is 180 per 15 minutes window.
#
# Perform following tasks
# * Clear the counter
# * Collect 200 tweets that mention Flatiron School using `.search()` method. (Use `language=en` to collect english tweets only)
# * Collect the top 30 @mentions from the all tweets that mention FlatironSchool.
# * Visualize the results as a wordcloud

# %%
# The search term you want to find
query = "FlatironSchool"
# Language code (follows ISO 639-1 standards)
language = "en"
tweetCount = 200

my_search = my_first_api.search(q=query, lang=language, tweet_mode='extended', count=tweetCount)

# [('@FlatironSchool', 83), ('@fulmolightning', 52), ('@pierre_rochard', 21), 
# ('@peterktodd', 19), ('@MsJisola', 17), ('@ElectrumWallet', 17), ('@BtcpayServer', 14), 
# ('@r0ckstardev', 13), ('@Blockstream', 12), ('@Excellion', 12), ('@rootzoll', 11), 
# ('@CryptoCloaks', 8), ('@CasaHODL', 7), ('@overtorment', 6), ('@CReckhow', 5), 
# ('@starkness', 4), ('@CodeNewbies', 4), ('@TeachFirst', 4), ('@jeetsidhu_', 3), ('@Snyke', 3)]

# %%
cnt = Counter()

for tweet in my_search:
    tags = []
    words = preprocess_tweet(tweet.full_text)
    for word in words:
        if word[0] == '@':
            tags.append(word)
    cnt.update(tags)

common_mentions = cnt.most_common(n=30)
common_mentions
# Out:
# [('@FlatironSchool', 53),
#  ('@Career_Karma', 18),
#  ('@timurmeyster', 10),
#  ('@LambdaSchool', 10),
#  ('@theohubs', 9),
#  ('@Patti__Carter', 9),
#  ('@RuthZaija', 9),
#  ('@rodneysampson', 7),
#  ('@meg_gutshall', 6),
#  ('@sindidev', 6),
#  ('@nerajno', 5),
#  ('@Flatiro', 5),
#  ('@MsJisola', 4),
#  ('@GretchenJacobi', 3),
#  ('@Jessica17324285', 3),
#  ('@flatironschool', 3),
#  ('@CvilleSoftEng', 2),
#  ('@Kingonomics', 2),
#  ('@Young_Guru', 2),
#  ('@ValeriaRagonese', 2),
#  ('@BekahHW', 2),
#  ('@Rosenberg1Shari', 2),
#  ('@heshiebee', 2),
#  ('@mmtconline', 1),
#  ('@WeWork', 1),
#  ('@veronica_hanus', 1),
#  ('@darlingsavage_', 1),
#  ('@IndianaUniv', 1),
#  ('@aviflombaum', 1),
#  ('@codebarWL', 1)]

# %% [markdown]
# Another common way to view dominant terms in a corpus of text is to visualize a wordcloud of top n terms. Here is an API reference for [WordCloud for Python](https://amueller.github.io/word_cloud/references.html).
# * Create a word cloud from top 20 mentions above to highlight who is being mentioned most.

# %%
common_freq = {}
for mention in common_mentions:
    common_freq[mention[0]] = mention[1]

type(common_freq), common_freq
# Out:
# (dict,
#  {'@FlatironSchool': 53,
#   '@Career_Karma': 18,
#   '@timurmeyster': 10,
#   '@LambdaSchool': 10,
#   '@theohubs': 9,
#   '@Patti__Carter': 9,
#   '@RuthZaija': 9,
#   '@rodneysampson': 7,
#   '@meg_gutshall': 6,
#   '@sindidev': 6,
#   '@nerajno': 5,
#   '@Flatiro': 5,
#   '@MsJisola': 4,
#   '@GretchenJacobi': 3,
#   '@Jessica17324285': 3,
#   '@flatironschool': 3,
#   '@CvilleSoftEng': 2,
#   '@Kingonomics': 2,
#   '@Young_Guru': 2,
#   '@ValeriaRagonese': 2,
#   '@BekahHW': 2,
#   '@Rosenberg1Shari': 2,
#   '@heshiebee': 2,
#   '@mmtconline': 1,
#   '@WeWork': 1,
#   '@veronica_hanus': 1,
#   '@darlingsavage_': 1,
#   '@IndianaUniv': 1,
#   '@aviflombaum': 1,
#   '@codebarWL': 1})

# %%
# Visualize the word cloud for top 20 mentions everytime flatiron school gets mentioned in a tweet
# !pip install wordcloud
import numpy as np
from PIL import Image
from os import path
import wordcloud
mask = np.array(Image.open("FS.png"))
cloud = wordcloud.WordCloud(max_font_size=50, max_words=100, background_color="white")

cloud.generate_from_frequencies(common_freq)

plt.figure(figsize=(15,10))
plt.imshow(cloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# This looks great. Try collecting a large number of tweets using the criteria seen previously and create a more populated word cloud. You can also customize and prettify it to your heart's content.
#
# ## From JSON to DataFrames
#
# So far, we have been processing our tweets directly from the JSON files. It may be desired for an advanced analystical experiment to store data as pandas dataframe and enjoy all the goodness of pandas, scikitlearn and buult in statistics. Let's try to select some selected parts of the tweet and save it nicely as pandas dataframe and csv file.
#
# #### Load `tweets.json`  and save following contents as pandas dataframe `tweet_json_df`
#     * id
#     * full_text
#     * favorite_count
#     * retweet_count
#     * created_at
#
# * Set some meaningful names for dataframe columns to store these values.
# * Print the dataframe head to inspect the contents
# * save data as "tweets.csv"

# %%
# Parse the JSON file, selecting above attributes for each tweet and saving as a new row in a pandas dataframe

file = open('tweets.json')
data = json.load(file)

# tweet_id	             text	                                         favorite_count	retweet_count	created_at
# 0	1056647627062661121	RT @RalstonReports: The turnout models are loo...	0	15	Sun Oct 28 20:43:20 +0000 2018
# 1	1056647041093373952	[Cheat Sheet] Python Basics For Data Science h...	2	1	Sun Oct 28 20:41:00 +0000 2018
# 2	1056640802401615872	RT @Popehat: NYT: Well, Okay, But Are People ...	0	620	Sun Oct 28 20:16:13 +0000 2018
# 3	1056639940438544384	https://t.co/txeJ3g9IMW	1	1	Sun Oct 28 20:12:47 +0000 2018
# 4	1056638994203729922	IBM and NVIDIA collaborate to expand machine l...	3	1	Sun Oct 28 20:09:02 +0000 2018

# %%
import pandas as pd
# df = pd.DataFrame()
ids = []
full_texts = []
favorite_counts = []
retweet_counts = []
created_ats = []
cols = ['id', 'full_text', 'favorite_count', 'retweet_count', 'created_at']
results = [ids, full_texts, favorite_counts, retweet_counts, created_ats]

for tweet in data[0:5]:
    ids.append(tweet['id'])
    full_texts.append(tweet['full_text'])
    favorite_counts.append(tweet['favorite_count'])
    retweet_counts.append(tweet['retweet_count'])
    created_ats.append(tweet['created_at'])
    
df = pd.DataFrame()
for i in range(len(cols)):
    df[cols[i]] = results[i]

df
# Out:
#                     id                                          full_text  \
# 0  1087454401911050242  Nine years since Citizens United, the amount o...
# 1  1087441491465854977  RT @Moonifyio: Fellow sponsor shoutout! #BGCLo...
# 2  1087424598151491585  If your New Year’s resolution involves stickin...
# 3  1087397097308110849  NEW SHOW: Muse are pleased to add Los Angeles ...
# 4  1087382991901474816  I’ve always drawn inspiration from what Dr. Ki...
#
#    favorite_count  retweet_count                      created_at
# 0           15563           5430  Mon Jan 21 20:58:27 +0000 2019
# 1               0              2  Mon Jan 21 20:07:09 +0000 2019
# 2               1              0  Mon Jan 21 19:00:02 +0000 2019
# 3             917            131  Mon Jan 21 17:10:45 +0000 2019
# 4          495501         116173  Mon Jan 21 16:14:42 +0000 2019

# %% [markdown]
# So there we have it. The skills that you have learned in this lab can be used towards data journalism, data science related articles etc. These skills will also come in handy for more advanced NLP techniques like topic modelling, sentiment analysis, emoticon analysis etc.

# %% [markdown]
# ## Level Up - Optional
#
# * Try generating more wordclouds from all the examples we saw in this lab.
# * Ask yourself an analytical question and mine Twitter to get tweets, process them in tweepy and visualize the results.
# * Count emoticons for smily face, frowning face, excited face etc. and see what are people's sentiments about a specific topic of interest i.e. Brexit, War in Syria, Best actor from last Oscars etc.
# * See which Twitter member is mentioning you the most at Twitter.
# * ON-going : Repeatedly mine twitter (say once per day) on a topic of interest and collect,parse,visualize tweets to see any changing trends.

# %% [markdown]
# ## Further Reading
#
# * [Introduction to NLP](https://blog.algorithmia.com/introduction-natural-language-processing-nlp/)
# * [Python/NLTK Language Processing](http://blog.chapagain.com.np/python-nltk-twitter-sentiment-analysis-natural-language-processing-nlp/)
# * [Applying NLP to Twitter in Python](https://dzone.com/articles/applying-nlp-to-tweets-with-python)
# * [Using the Twitter API and NLP to analyze the tweets of different users.](https://towardsdatascience.com/twitter-api-and-nlp-7a386758eb31)

# %% [markdown]
# ## Summary
#
# In this lab, we saw how to collect data from twitter using OAuth and collect Tweets under for a number of different use cases. We looked at parsing the JSON file for collecting relevant information and also visualized the outcome of our processing. As a reminder, this lab is supposed to be a data engineering oriented lab, i.e. getting data ready for processing. We shall see more on NLP later in next module of the course. This lab should get you all ready for some serious experiments like sentiment analysis , predictions and classification tasks.
